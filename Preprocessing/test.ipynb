# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("../Data/2_lab.csv", index_col=False)

# %%
df.head()
# Out:
#                                     name  release_date  required_age  price  \
# 0             Black Dragon Mage Playtest   Aug 1, 2023             0   0.00
# 1  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016             0   5.24
# 2      Mystery Solitaire The Black Raven   May 6, 2019             0   4.99
# 3            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024             0   8.99
# 4                          Maze Quest VR  Apr 24, 2025             0   4.99
#
#    dlc_count                               detailed_description  \
# 0          0                                                NaN
# 1          0  Springtime, April: when the cherry trees come ...
# 2          0  Immerse yourself in the most beloved, mystical...
# 3          1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4          0  Its not just a Maze; its a Quest! Enter the ca...
#
#                                       about_the_game  \
# 0                                                NaN
# 1  Springtime, April: when the cherry trees come ...
# 2  Immerse yourself in the most beloved, mystical...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4  Its not just a Maze; its a Quest! Enter the ca...
#
#                                    short_description reviews  \
# 0                                                NaN     NaN
# 1  Spring has come, and our protagonist, Yukinari...     NaN
# 2      Discover an entrancing and spectacular world!     NaN
# 3  Yuha! I'll start the broadcast! Hakko's extrem...     NaN
# 4  Its not just a Maze; its a Quest! Enter the ca...     NaN
#
#                                         header_image  ... positive negative  \
# 0  https://shared.akamai.steamstatic.com/store_it...  ...        0        0
# 1  https://shared.akamai.steamstatic.com/store_it...  ...      252        3
# 2  https://shared.akamai.steamstatic.com/store_it...  ...       21        3
# 3  https://shared.akamai.steamstatic.com/store_it...  ...        0        0
# 4  https://shared.akamai.steamstatic.com/store_it...  ...        0        0
#
#   estimated_owners  average_playtime_forever  average_playtime_2weeks  \
# 0            0 - 0                         0                        0
# 1        0 - 20000                         8                        0
# 2        0 - 20000                         0                        0
# 3        0 - 20000                         0                        0
# 4        0 - 20000                         0                        0
#
#    median_playtime_forever  median_playtime_2weeks discount  peak_ccu  \
# 0                        0                       0        0         0
# 1                        8                       0       65         0
# 2                        0                       0        0         0
# 3                        0                       0        0         1
# 4                        0                       0        0         0
#
#                                                 tags
# 0                                                 []
# 1  {'Adventure': 27, 'Visual Novel': 19, 'Anime':...
# 2  {'Casual': 83, 'Card Game': 52, 'Solitaire': 4...
# 3                                                 []
# 4                                                 []
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['name', 'release_date', 'required_age', 'price', 'dlc_count',
#        'detailed_description', 'about_the_game', 'short_description',
#        'reviews', 'header_image', 'website', 'support_url', 'support_email',
#        'windows', 'mac', 'linux', 'metacritic_score', 'metacritic_url',
#        'achievements', 'recommendations', 'notes', 'supported_languages',
#        'full_audio_languages', 'packages', 'developers', 'publishers',
#        'categories', 'genres', 'screenshots', 'movies', 'user_score',
#        'score_rank', 'positive', 'negative', 'estimated_owners',
#        'average_playtime_forever', 'average_playtime_2weeks',
#        'median_playtime_forever', 'median_playtime_2weeks', 'discount',
#        'peak_ccu', 'tags'],
#       dtype='object')

# %%
model = SentenceTransformer("all-MiniLM-l6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-l6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
embendings = model.encode(df["name"].astype(str).tolist(), batch_size=64, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1916 [00:00<?, ?it/s]

# %%
embendings.shape
# Out:
# (122611, 384)

# %%
n_comp = 32
pca = PCA(n_components=n_comp)
pca_features = pca.fit_transform(embendings)

# %%
pca_features.shape
# Out:
# (122611, 32)

# %%
pca_cols = [f'name_pca_{i}' for i in range(n_comp)]
df_pca = pd.DataFrame(pca_features, columns=pca_cols, index=df.index)

df_ = pd.concat([df, df_pca], axis=1)

# %%
len(df_.columns)
# Out:
# 74

# %%
df_.to_csv("../Data/2_lab_proc.csv", index=False)
