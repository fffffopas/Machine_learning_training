# %%
import numpy as np
import pandas as pd
import os

json_path = "../Data/1_lab.json"

# %%
df = pd.read_json(json_path)
df = df.T
df.head()
# Out:
#                                           name  release_date required_age  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023            0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016            0
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019            0
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024            0
# 3631080                          Maze Quest VR  Apr 24, 2025            0
#
#         price dlc_count                               detailed_description  \
# 2539430   0.0         0
# 496350   5.24         0  Springtime, April: when the cherry trees come ...
# 1034400  4.99         0  Immerse yourself in the most beloved, mystical...
# 3292190  8.99         1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 3631080  4.99         0  Its not just a Maze; its a Quest! Enter the ca...
#
#                                             about_the_game  \
# 2539430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122611 entries, 2539430 to 4141790
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   name                      122611 non-null  object
#  1   release_date              122611 non-null  object
#  2   required_age              122611 non-null  object
#  3   price                     122611 non-null  object
#  4   dlc_count                 122611 non-null  object
#  5   detailed_description      122611 non-null  object
#  6   about_the_game            122611 non-null  object
#  7   short_description         122611 non-null  object
#  8   reviews                   122611 non-null  object
#  9   header_image              122611 non-null  object
#  10  website                   122611 non-null  object
#  11  support_url               122611 non-null  object
#  12  support_email             122611 non-null  object
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 26
#      23     _df = _df.reset_index().set_index("AppID")
#      24     return _df
# ---> 26 df = read_convert_json_dataset()
#
# Cell In[7], line 21, in read_convert_json_dataset()
#      19         _df[col] = _df[col].apply(lambda entries: convert_dict_to_string(entries))
#      20     if isinstance(_df.loc[546560][col], list):
# ---> 21         if isinstance(_df.loc[546560][col][0], str): # Avoids trying to convert the "Packages" column
#      22             _df[col] = _df[col].apply(lambda entries: ",".join(entries))
#      23 _df = _df.reset_index().set_index("AppID")
#
# IndexError: list index out of range

# %%
df.to_csv("../Data/1_lab.csv")

# %%
df = pd.read_csv("../Data/1_lab.csv")

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df["support_email"]
# Out:
# 0                                 NaN
# 1              support@mangagamer.com
# 2                  support@8floor.net
# 3               yujingamesc@gmail.com
# 4         support@realityexpanded.com
#                      ...
# 122606         yuanhao@taoxinsoft.com
# 122607             info@pokerfate.com
# 122608           argameware@gmail.com
# 122609      support@sevenmoons.com.br
# 122610           student@vantan.co.jp
# Name: support_email, Length: 122611, dtype: object

# %%
df["support_url"]
# Out:
# 0                                          NaN
# 1                        http://mangagamer.com
# 2         https://www.facebook.com/8FloorGames
# 3                                          NaN
# 4              https://www.realityexpanded.com
#                           ...
# 122606                                     NaN
# 122607               https://www.pokerfate.com
# 122608            https://arraubigameware.com/
# 122609                                     NaN
# 122610                                     NaN
# Name: support_url, Length: 122611, dtype: object

# %%
df.to_csv("../Data/2_lab.csv",index=False )
